# %% [markdown]
# ## Домашнее задание №2
# ## Pandas

# %% [markdown]
# 1. Импортируйте пандас как pd и считайте файл TSLA.csv (https://www.kaggle.com/efekurdoglu/teslastockprice/data) как датафрейм

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('TSLA.csv');

# %% [markdown]
# 2. Удалите из столбца Close значения, целые части которых кратны 6

# %%
df.Close = df.Close.apply(lambda x: np.nan if x % 6 == 0 else x)
df
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2010-06-29    3.800000    5.000000    3.508000    4.778000    4.778000
# 1     2010-06-30    5.158000    6.084000    4.660000    4.766000    4.766000
# 2     2010-07-01    5.000000    5.184000    4.054000    4.392000    4.392000
# 3     2010-07-02    4.600000    4.620000    3.742000    3.840000    3.840000
# 4     2010-07-06    4.000000    4.000000    3.166000    3.222000    3.222000
# ...          ...         ...         ...         ...         ...         ...
# 2572  2020-09-16  439.869995  457.790009  435.309998  441.760010  441.760010
# 2573  2020-09-17  415.600006  437.790009  408.000000  423.429993  423.429993
# 2574  2020-09-18  447.940002  451.000000  428.799988  442.149994  442.149994
# 2575  2020-09-21  453.130005  455.679993  407.070007  449.390015  449.390015
# 2576  2020-09-22  429.600006  437.760010  417.600006  424.230011  424.230011
#
#          Volume
# 0      93831500
# 1      85935500
# 2      41094000
# 3      25699000
# 4      34334500
# ...         ...
# 2572   72279300
# 2573   76779200
# 2574   86406800
# 2575  109476800
# 2576   73640900
#
# [2577 rows x 7 columns]

# %% [markdown]
# 3. Теперь попробуйте заполнить пропуски средним значением в столбце, потом минимумом, потом медианой

# %%
df.fillna(df.mean()) #заполнение пропуском средним значением
# Out:
# C:\Users\Valery\AppData\Local\Temp\ipykernel_3824\1395391046.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.fillna(df.mean()) #заполнение пропуском средним значением
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2010-06-29    3.800000    5.000000    3.508000    4.778000    4.778000
# 1     2010-06-30    5.158000    6.084000    4.660000    4.766000    4.766000
# 2     2010-07-01    5.000000    5.184000    4.054000    4.392000    4.392000
# 3     2010-07-02    4.600000    4.620000    3.742000    3.840000    3.840000
# 4     2010-07-06    4.000000    4.000000    3.166000    3.222000    3.222000
# ...          ...         ...         ...         ...         ...         ...
# 2572  2020-09-16  439.869995  457.790009  435.309998  441.760010  441.760010
# 2573  2020-09-17  415.600006  437.790009  408.000000  423.429993  423.429993
# 2574  2020-09-18  447.940002  451.000000  428.799988  442.149994  442.149994
# 2575  2020-09-21  453.130005  455.679993  407.070007  449.390015  449.390015
# 2576  2020-09-22  429.600006  437.760010  417.600006  424.230011  424.230011
#
#          Volume
# 0      93831500
# 1      85935500
# 2      41094000
# 3      25699000
# 4      34334500
# ...         ...
# 2572   72279300
# 2573   76779200
# 2574   86406800
# 2575  109476800
# 2576   73640900
#
# [2577 rows x 7 columns]

# %%
df.fillna(df.min()) #заполнение пропуском минимальным значением
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2010-06-29    3.800000    5.000000    3.508000    4.778000    4.778000
# 1     2010-06-30    5.158000    6.084000    4.660000    4.766000    4.766000
# 2     2010-07-01    5.000000    5.184000    4.054000    4.392000    4.392000
# 3     2010-07-02    4.600000    4.620000    3.742000    3.840000    3.840000
# 4     2010-07-06    4.000000    4.000000    3.166000    3.222000    3.222000
# ...          ...         ...         ...         ...         ...         ...
# 2572  2020-09-16  439.869995  457.790009  435.309998  441.760010  441.760010
# 2573  2020-09-17  415.600006  437.790009  408.000000  423.429993  423.429993
# 2574  2020-09-18  447.940002  451.000000  428.799988  442.149994  442.149994
# 2575  2020-09-21  453.130005  455.679993  407.070007  449.390015  449.390015
# 2576  2020-09-22  429.600006  437.760010  417.600006  424.230011  424.230011
#
#          Volume
# 0      93831500
# 1      85935500
# 2      41094000
# 3      25699000
# 4      34334500
# ...         ...
# 2572   72279300
# 2573   76779200
# 2574   86406800
# 2575  109476800
# 2576   73640900
#
# [2577 rows x 7 columns]

# %%
df.fillna(df.median) #заполнение пропуском медианным значением
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2010-06-29    3.800000    5.000000    3.508000       4.778    4.778000
# 1     2010-06-30    5.158000    6.084000    4.660000       4.766    4.766000
# 2     2010-07-01    5.000000    5.184000    4.054000       4.392    4.392000
# 3     2010-07-02    4.600000    4.620000    3.742000        3.84    3.840000
# 4     2010-07-06    4.000000    4.000000    3.166000       3.222    3.222000
# ...          ...         ...         ...         ...         ...         ...
# 2572  2020-09-16  439.869995  457.790009  435.309998   441.76001  441.760010
# 2573  2020-09-17  415.600006  437.790009  408.000000  423.429993  423.429993
# 2574  2020-09-18  447.940002  451.000000  428.799988  442.149994  442.149994
# 2575  2020-09-21  453.130005  455.679993  407.070007  449.390015  449.390015
# 2576  2020-09-22  429.600006  437.760010  417.600006  424.230011  424.230011
#
#          Volume
# 0      93831500
# 1      85935500
# 2      41094000
# 3      25699000
# 4      34334500
# ...         ...
# 2572   72279300
# 2573   76779200
# 2574   86406800
# 2575  109476800
# 2576   73640900
#
# [2577 rows x 7 columns]

# %% [markdown]
# 4. А теперь попробуйте заполнить эти пропуски средним между всеми значениями, кратным 5 и всеми значениями, кратным 7 (т.е. выберите все значение, кратные 5 и найдите их среднее, а потом все значение, кратные 7, найдите среднее среди них, а потом усредните два полученных значения).

# %%
## df.loc[lambda x: x.Close % 5 == 0].mean().Close - среднее значение для кратных 5
## df.loc[lambda x: x.Close % 7 == 0].mean().Close - среднее значение для кратных 7

#среднее значение для кратных 5 и 7
meanDf = df.loc[lambda x: x.Close % 5 == 0].mean().Close + df.loc[lambda x: x.Close % 7 == 0].mean().Close / 2

df = df.fillna(meanDf) #заполнить и сохранить средним значением
df
# Out:
# C:\Users\Valery\AppData\Local\Temp\ipykernel_3824\683222371.py:5: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   meanDf = df.loc[lambda x: x.Close % 5 == 0].mean().Close + df.loc[lambda x: x.Close % 7 == 0].mean().Close / 2
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2010-06-29    3.800000    5.000000    3.508000    4.778000    4.778000
# 1     2010-06-30    5.158000    6.084000    4.660000    4.766000    4.766000
# 2     2010-07-01    5.000000    5.184000    4.054000    4.392000    4.392000
# 3     2010-07-02    4.600000    4.620000    3.742000    3.840000    3.840000
# 4     2010-07-06    4.000000    4.000000    3.166000    3.222000    3.222000
# ...          ...         ...         ...         ...         ...         ...
# 2572  2020-09-16  439.869995  457.790009  435.309998  441.760010  441.760010
# 2573  2020-09-17  415.600006  437.790009  408.000000  423.429993  423.429993
# 2574  2020-09-18  447.940002  451.000000  428.799988  442.149994  442.149994
# 2575  2020-09-21  453.130005  455.679993  407.070007  449.390015  449.390015
# 2576  2020-09-22  429.600006  437.760010  417.600006  424.230011  424.230011
#
#          Volume
# 0      93831500
# 1      85935500
# 2      41094000
# 3      25699000
# 4      34334500
# ...         ...
# 2572   72279300
# 2573   76779200
# 2574   86406800
# 2575  109476800
# 2576   73640900
#
# [2577 rows x 7 columns]

# %% [markdown]
# 5. Импортируйте matplotlib.pyplot как plt. Постройте графики получишвихся наборов значений. Чтобы получше разглядеть, найдите как в pyplot задать размер графика и поставьте побольше.

# %%
from matplotlib.pyplot import figure

figure(figsize=(12,5), dpi=100)

df.Close.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# 6. Приведите столбец High к строковому типу. Найдите все строки, где содержится цифра 9.
# Подсказка: загуглите pandas.str

# %%
df = df.High.astype("string")
df[(df.str.contains('9') == True)]
# Out:
# 23           4.194
# 24            4.39
# 28           3.996
# 29            3.93
# 32            3.69
#            ...
# 2568     398.98999
# 2571    461.940002
# 2572    457.790009
# 2573    437.790009
# 2575    455.679993
# Name: High, Length: 1255, dtype: string

# %% [markdown]
# 7. А теперь найдите в этом столбце строки, которые содержат цифру 4, но не содержат цифру 8.

# %%
df[(df.str.contains("4") == True) & (df.str.contains("8") == False)]
# Out:
# 3             4.62
# 4              4.0
# 6            3.504
# 8            3.614
# 10            4.03
#            ...
# 2572    457.790009
# 2573    437.790009
# 2574         451.0
# 2575    455.679993
# 2576     437.76001
# Name: High, Length: 827, dtype: string

# %% [markdown]
# 8. И наконец найдите в столбце Hihg (пусть там все еще будет строковый тип) такие строчки, у которых в дробной части есть цифра 3 и замените ее на 4.
# Подсказка: может помочь метод split.
# А потом замените эти значения в датафрейме на какое-нибудь слово. Например, лопата.

# %% [markdown]
# Шложна

# %% [markdown]
# 9. Нормализовать столбец Open

# %%
df = pd.read_csv('TSLA.csv');

# %%
df.Open.apply(lambda x: (x-df.Open.min())/(df.Open.max()-df.Open.min()))
# Out:
# 0       0.001146
# 1       0.003868
# 2       0.003552
# 3       0.002750
# 4       0.001547
#           ...
# 2572    0.875188
# 2573    0.826543
# 2574    0.891364
# 2575    0.901766
# 2576    0.854604
# Name: Open, Length: 2577, dtype: float64

# %% [markdown]
# 10. И, правда наконец, создайте пустой датафрейм с такими же колонками, как TSLA. Пусть в нем будет 10 строк. И пусть они будут заполнены такими значениями: в i-й строке j-го столбца должна быть j-ая степень числа i+j. Добавьте этот датафрейм в конец исходного.
# Используйте метод tail, чтобы увидеть конец полученного датафрейма и порадоваться, что у вас все получилось и вы готовы реально обрабатывать датафреймы и заниматься дата сасом.

# %%
me = pd.DataFrame()
for i in range (0, 10):
    for j in range (0, 7):
        me.loc[i, j] = (i+j)**j
me
# Out:
#      0     1      2       3        4         5           6
# 0  1.0   1.0    4.0    27.0    256.0    3125.0     46656.0
# 1  1.0   2.0    9.0    64.0    625.0    7776.0    117649.0
# 2  1.0   3.0   16.0   125.0   1296.0   16807.0    262144.0
# 3  1.0   4.0   25.0   216.0   2401.0   32768.0    531441.0
# 4  1.0   5.0   36.0   343.0   4096.0   59049.0   1000000.0
# 5  1.0   6.0   49.0   512.0   6561.0  100000.0   1771561.0
# 6  1.0   7.0   64.0   729.0  10000.0  161051.0   2985984.0
# 7  1.0   8.0   81.0  1000.0  14641.0  248832.0   4826809.0
# 8  1.0   9.0  100.0  1331.0  20736.0  371293.0   7529536.0
# 9  1.0  10.0  121.0  1728.0  28561.0  537824.0  11390625.0

# %%
me.rename(columns = {0: 'Date', 1: 'Open', 2: 'High', 3: 'Low', 4: 'Close', 5: 'Adj Close', 6: 'Volume'}, inplace = True)
me
# Out:
#    Date  Open   High     Low    Close  Adj Close      Volume
# 0   1.0   1.0    4.0    27.0    256.0     3125.0     46656.0
# 1   1.0   2.0    9.0    64.0    625.0     7776.0    117649.0
# 2   1.0   3.0   16.0   125.0   1296.0    16807.0    262144.0
# 3   1.0   4.0   25.0   216.0   2401.0    32768.0    531441.0
# 4   1.0   5.0   36.0   343.0   4096.0    59049.0   1000000.0
# 5   1.0   6.0   49.0   512.0   6561.0   100000.0   1771561.0
# 6   1.0   7.0   64.0   729.0  10000.0   161051.0   2985984.0
# 7   1.0   8.0   81.0  1000.0  14641.0   248832.0   4826809.0
# 8   1.0   9.0  100.0  1331.0  20736.0   371293.0   7529536.0
# 9   1.0  10.0  121.0  1728.0  28561.0   537824.0  11390625.0

# %%
df.append(me)
# Out:
# C:\Users\Valery\AppData\Local\Temp\ipykernel_3824\184343138.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df.append(me)
#           Date    Open     High       Low      Close   Adj Close      Volume
# 0   2010-06-29   3.800    5.000     3.508      4.778       4.778  93831500.0
# 1   2010-06-30   5.158    6.084     4.660      4.766       4.766  85935500.0
# 2   2010-07-01   5.000    5.184     4.054      4.392       4.392  41094000.0
# 3   2010-07-02   4.600    4.620     3.742      3.840       3.840  25699000.0
# 4   2010-07-06   4.000    4.000     3.166      3.222       3.222  34334500.0
# ..         ...     ...      ...       ...        ...         ...         ...
# 5          1.0   6.000   49.000   512.000   6561.000  100000.000   1771561.0
# 6          1.0   7.000   64.000   729.000  10000.000  161051.000   2985984.0
# 7          1.0   8.000   81.000  1000.000  14641.000  248832.000   4826809.0
# 8          1.0   9.000  100.000  1331.000  20736.000  371293.000   7529536.0
# 9          1.0  10.000  121.000  1728.000  28561.000  537824.000  11390625.0
#
# [2587 rows x 7 columns]
